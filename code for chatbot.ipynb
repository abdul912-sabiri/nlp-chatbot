# %%
import random
def greet(bot_name, birth_year):
    print("Hello! My name is {0}.".format(bot_name))
    print("I was created in {0}.".format(birth_year))


def remind_name():
    print('Please, remind me your name.')
    name = input()
    print("What a great name you have, {0}!".format(name))


def remind_fathername():
    print('Please, remind me your father\'s name.')
    father_name = input()
    print("What a great name your father has, {0}!".format(father_name))


def guess_age():
    print('Let me guess your age.')
    print('Enter remainders of dividing your age by 3, 5 and 7.')

    rem3 = int(input())
    rem5 = int(input())
    rem7 = int(input())
    age = (rem3 * 70 + rem5 * 21 + rem7 * 15) % 105

    print("Your age is {0}; that's a good time to start programming!".format(age))


def count():
    print('Now I will prove to you that I can count to any number you want.')
    num = int(input())

    counter = 0
    while counter <= num:
        print("{0} !".format(counter))
        counter += 1

def logical_question():
    print("Let's test your logical reasoning skills.")
    print("If all birds can fly, and penguins are birds, can we conclude that penguins can fly?")
    print("1. Yes")
    print("2. No")
    m6
    8
    answer = 1  # The correct answer is 1 (Yes)
    guess = int(input())

    if guess == answer:
        print("That's correct! You have good logical reasoning skills.")
    else:
        print("Sorry, that's not correct. Keep practicing your logic!")

    #print('.................................')
    #print('.................................')
def test():
    print("Let's test your programming knowledge.")
    print("Why do we use methods?")
    print("1. To repeat a statement multiple times.")
    print("2. To decompose a program into several small subroutines.")
    print("3. To determine the execution time of a program.")
    print("4. To interrupt the execution of a program.")

    answer = 2
    guess = int(input())
    while guess != answer:
        print("Please, try again.")
        guess = int(input())

    print('Completed, have a nice day!')
    print('.................................')
    print('.................................')
    print('.................................')


def end():
    print('Congratulations, have a nice day!')
    print('.................................')
    print('.................................')
    print('.................................')
    input()

greet('Alex', '2023')  # change it as you need
remind_name()
remind_fathername()
guess_age()
count()
test()
logical_question()
end()
# Out:
# Hello! My name is Alex.
# I was created in 2023.
# Please, remind me your name.
# Abdul
# What a great name you have, Abdul!
# Please, remind me your father's name.
# fazil ali
# What a great name your father has, fazil ali!
# Let me guess your age.
# Enter remainders of dividing your age by 3, 5 and 7.
# 4
# 7
# 3
# Your age is 52; that's a good time to start programming!
# Now I will prove to you that I can count to any number you want.
# 1
# 0 !
# 1 !
# Let's test your programming knowledge.
# Why do we use methods?
# 1. To repeat a statement multiple times.
# 2. To decompose a program into several small subroutines.
# 3. To determine the execution time of a program.
# 4. To interrupt the execution of a program.
# 2
# Completed, have a nice day!
# .................................
# .................................
# .................................
# Let's test your logical reasoning skills.
# If all birds can fly, and penguins are birds, can we conclude that penguins can fly?
# ...
